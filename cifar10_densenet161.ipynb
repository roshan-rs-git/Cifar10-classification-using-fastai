# %%
import zipfile as ZipFile
from google.colab import files
from fastai import *
from fastai.vision import *
from PIL import Image

# %%
url="https://files.fast.ai/data/examples/cifar10"
path=untar_data(url)
# Out:
# Downloading https://files.fast.ai/data/examples/cifar10.tgz

# %%
np.random.seed(24)

# %%
tfms = get_transforms(do_flip=True)

# %%
 data=ImageDataBunch.from_folder(path, valid_pct=0.2, ds_tfms=tfms, size=224, bs=16).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/transform.py:247: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   return _solve_func(B,A)[0][:,0]

# %%
data.show_batch(rows=4, figsize=(8, 8))

# %%
learn = cnn_learner(data, models.densenet161, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /root/.cache/torch/hub/checkpoints/densenet161-8d451a50.pth
#   0%|          | 0.00/110M [00:00<?, ?B/s]

# %%
 learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.324545</td>
#       <td>0.174256</td>
#       <td>0.942417</td>
#       <td>39:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.182119</td>
#       <td>0.104290</td>
#       <td>0.963750</td>
#       <td>39:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
I=open_image("/content/sample_data/0002.png")
I
# Out:
# Image (3, 32, 32)

# %%
pred_class,_,_ = learn.predict(I)
pred_class
# Out:
# Category tensor(9)

# %%
J=open_image("/content/sample_data/0001.png")
J
# Out:
# Image (3, 32, 32)

# %%
pred_class,_,_ = learn.predict(J)
pred_class
# Out:
# Category tensor(8)

# %%
K=open_image("/content/sample_data/0017.png")
K
# Out:
# Image (3, 32, 32)

# %%
pred_class,_,_ = learn.predict(K)
pred_class
# Out:
# Category tensor(6)
